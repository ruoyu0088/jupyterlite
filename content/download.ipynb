# %%
from helper.jupyterlite import download_folder

# %%
download_folder()
# Out:
# <a download="jupyterlite_files.zip" href="blob:http://127.0.0.1:8000/1ac032d8-f946-498e-bf2b-5b7d607f507a">Download jupyterlite_files.zip</a>
