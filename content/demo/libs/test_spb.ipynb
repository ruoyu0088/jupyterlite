# %%
import k3d
from sympy import *
from spb import *
from bokeh.io import output_notebook
output_notebook()

# %%
x = symbols("x")
p = plot(sin(x), cos(x), log(x), backend=MB, size=(5, 3))

# %%
p = plot(sin(x), cos(x), log(x), backend=BB, size=(500, 300))

# %%
p = plot(sin(x), cos(x), log(x), backend=PB, size=(500, 300))

# %%
u, v = symbols("u, v")
r = 2 + sin(7 * u + 5 * v)
expr = (
    r * cos(u) * sin(v),
    r * sin(u) * sin(v),
    r * cos(v)
)
p = plot3d_parametric_surface(*expr, (u, 0, 2 * pi), (v, 0, pi), "expr", backend=MB, use_cm=True, size=(5, 3))

# %%
p = plot3d_parametric_surface(*expr, (u, 0, 2 * pi), (v, 0, pi), "expr", backend=KB, use_cm=True, size=(500, 300))

# %%
from sympy.vector import CoordSys3D, gradient

u, v = symbols("u, v")
N = CoordSys3D("N")
i, j, k = N.base_vectors()
xn, yn, zn = N.base_scalars()

t = 0.35    # half-cone angle in radians
expr = -xn**2 * tan(t)**2 + yn**2 + zn**2    # cone surface equation
g = gradient(expr)
n = g / g.magnitude()    # unit normal vector
n1, n2 = 10, 20 # number of discretization points for the vector field

# cone surface to discretize vector field (low numb of discret points)
cone_discr = surface_parametric(
   u / tan(t), u * cos(v), u * sin(v), (u, 0, 1), (v, 0 , 2*pi),
   n1=n1, n2=n2)[0]
g = graphics(
   surface_parametric(
      u / tan(t), u * cos(v), u * sin(v), (u, 0, 1), (v, 0 , 2*pi),
      rendering_kw={"opacity": 1}, wireframe=True,
      wf_n1=n1, wf_n2=n2, wf_rendering_kw={"width": 0.004}),
   vector_field_3d(
      n, range1=(xn, -5, 5), range2=(yn, -5, 5), range3=(zn, -5, 5),
      use_cm=False, slice=cone_discr,
      quiver_kw={"scale": 0.5, "pivot": "tail"}
   ),
   backend=KB)

# %%
from spb.utils import get_environment

get_environment??

# %%
get_ipython().__class__
