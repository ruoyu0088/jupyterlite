# %% [markdown]
# # Lorenz attractor
#
# In this Notebook we explore the Lorenz system of differential equations:
#
# $$
# \begin{aligned}
# \dot{x} & = \sigma(y-x) \\
# \dot{y} & = \rho x - y - xz \\
# \dot{z} & = -\beta z + xy
# \end{aligned}
# $$
#
# This is one of the classic systems in non-linear differential equations. It exhibits a range of different behaviors as the parameters (\\(\sigma\\), \\(\beta\\), \\(\rho\\)) are varied.

# %%
import numpy as np
from scipy import integrate
import plotly.graph_objects as go
from ipywidgets import FloatSlider, IntSlider, VBox, interactive_output
import ipywidgets as widgets

# %%
def solve_lorenz(N=10, angle=0.0, max_time=4.0, sigma=10.0, beta=8./3, rho=28.0):
    def lorenz_deriv(x_y_z, t0, sigma=sigma, beta=beta, rho=rho):
        x, y, z = x_y_z
        return [sigma * (y - x), x * (rho - z) - y, x * y - beta * z]

    np.random.seed(1)
    x0 = -15 + 30 * np.random.random((N, 3))
    t = np.linspace(0, max_time, int(250 * max_time))
    x_t = np.asarray([integrate.odeint(lorenz_deriv, x0i, t) for x0i in x0])
    return t, x_t

# Create figure widget
fig = go.FigureWidget()
fig.add_trace(go.Scatter3d(mode='lines', line=dict(width=1)))

def update_plot(angle=0.0, max_time=4.0, N=10, sigma=10.0, rho=28.0):
    t, x_t = solve_lorenz(N=N, angle=angle, max_time=max_time, sigma=sigma, rho=rho)
    
    current_traces = len(fig.data)

    with fig.batch_update():
        # Update existing traces
        for i in range(min(current_traces, N)):
            x, y, z = x_t[i, :, :].T
            fig.data[i].x = x
            fig.data[i].y = y
            fig.data[i].z = z
        
        # Add new traces if N > current_traces
        for i in range(current_traces, N):
            x, y, z = x_t[i, :, :].T
            fig.add_trace(go.Scatter3d(x=x, y=y, z=z, mode='lines', line=dict(width=1)))
    
        if len(fig.data) > N:
            fig.data = fig.data[:N]
            
        # Update layout
        fig.update_layout(
            scene=dict(
                xaxis_title='X',
                yaxis_title='Y',
                zaxis_title='Z',
                camera=dict(eye=dict(
                    x=np.cos(np.radians(angle)), 
                    y=np.sin(np.radians(angle)), 
                    z=0.5
                ))
            ),
            width=700, height=500,
            title="Lorenz System Simulation"
        )

# Slider styling for wider sliders and update on release
slider_layout = widgets.Layout(width='600px')

angle_slider = FloatSlider(value=0.0, min=0.0, max=360.0, step=1.0, description='angle',
                           layout=slider_layout, continuous_update=False)
max_time_slider = FloatSlider(value=4.0, min=0.1, max=4.0, step=0.1, description='max_time',
                              layout=slider_layout, continuous_update=False)
N_slider = IntSlider(value=10, min=0, max=50, step=1, description='N',
                     layout=slider_layout, continuous_update=False)
sigma_slider = FloatSlider(value=10.0, min=0.0, max=50.0, step=0.5, description='sigma',
                           layout=slider_layout, continuous_update=False)
rho_slider = FloatSlider(value=28.0, min=0.0, max=50.0, step=0.5, description='rho',
                         layout=slider_layout, continuous_update=False)

ui = VBox([angle_slider, max_time_slider, N_slider, sigma_slider, rho_slider])
out = interactive_output(update_plot, {
    'angle': angle_slider,
    'max_time': max_time_slider,
    'N': N_slider,
    'sigma': sigma_slider,
    'rho': rho_slider
})

display(ui, fig, out)
# Out:
# VBox(children=(FloatSlider(value=0.0, continuous_update=False, description='angle', layout=Layout(width='600px…
# FigureWidget({
#     'data': [{'line': {'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid':
line': {'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': '2d76005a-db77-4a7d-b8e6-36f435fa6c8d',
#               'x': {'bdata': ('OJ21DMN0FEDCnfLHXk4TQBw2pzNISB' ... 'kYAzclwG2NZDoEQiXA2jZyUrhKJcA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('yKpI/srYA8BUupg8+TD/vzKCM21/Kf' ... 'tpNWYmwJiU22lMOCbA6UCJGwMHJsA='),
#                     'dtype': 'f8'},
#               'z': {'bdata': ('oIfXXc4r/D8c8784wSv7P8E9VifOX/' ... '1y3fk8QFKDYsraIz1AnHYw05tMPUA='),
#                     'dtype': 'f8'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': '21acd173-f240-4904-8345-35ecb3b6f7f6',
#               'x': {'bdata': ('6d90GKiTJcDK0EWst3glwP52NhAsbi' ... 'aalikXQEQz+61DHBZA5DJO2bgWFUA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('IH6pPykdIsBBVFDUCakjwH1J2kfYKi' ... 'pz++PrvwoZRPHXTO6/OPdtHnMr8L8='),
#                     'dtype': 'f8'},
#               'z': {'bdata': ('0qlew28LIkBUFrYynKkiQPl3p2IYVi' ... 'i+Y6k/QMKXal8OTj9ASgQuAY3zPkA='),
#                     'dtype': 'f8'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': '92d03f19-bfb3-46b7-a939-673c2d3b3791',
#               'x': {'bdata': ('XksFcH8YLEBeTAJFaZoqQNyE0FrRQy' ... 'MrwnwWwEyuu8W1DBfADaW8Y9OgF8A='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('HKWb95tjFsCIb8uuz2cRwNTFzfj+RA' ... 'RHICoiwBUR1KjgpSLAWebbSSUkI8A='),
#                     'dtype': 'f8'},
#               'z': {'bdata': ('rLTFlyYUF0AHQB2pIcAVQLDxKnSJvh' ... '/F6IMvQCSsdV8LmS9AjwAIZomzL0A='),
#                     'dtype': 'f8'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': '78df78ec-edc4-4768-a66a-0557ae70f47c',
#               'x': {'bdata': ('wNZ8XlaVJkCwzXsCO7ImQKPwPo0x8S' ... 'Bjiz6OvznQkWmKFo6/jtSC2LEEjr8='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('Sva3iSitJ0BpB4DmODUrQH34aWSyry' ... 'kp4TqJv+3jYUz5R4u/+h+hTjlUjb8='),
#                     'dtype': 'f8'},
#               'z': {'bdata': ('XCnHjbjlKMBOlP7UbHwnwGUOWJLe6y' ... 'hkOmUkQLT/AbXGLSRAhLGKy+n2I0A='),
#                     'dtype': 'f8'}},
#              {'line': {'width': 1},
#               'mode': 'lines',
#               'type': 'scatter3d',
#               'uid': '378f27a8-313a-4dbb-b0a5-f9134c30a30d',
#               'x': {'bdata': ('e77zVx6oK8BSZN87FGIrwDdDdF/HLy' ... 'XbcyEwQCYuAoJVPzBAwCleCphWMEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('ykAOnmfPI8A0YV9ivIklwIMd1F9lMS' ... '/pxFszQFOObvk52DJAke4i/VNGMkA='),
#                     'dtype': 'f8'},
#               'z': {'bdata': ('8mmH00SwJkAScyvCo5QnQNyNT/Oiiy' ... 'FfhydBQOa6t0qWlkFADS2UaPkAQkA='),
#                     'dtype': 'f8'}}],
#     'layout': {'height': 500,
#                'scene': {'camera': {'eye': {'x': np.float64(1.0), 'y': np.float64(0.0), 'z': 0.5}},
#                          'xaxis': {'title': {'text': 'X'}},
#                          'yaxis': {'title': {'text': 'Y'}},
#                          'zaxis': {'title': {'text': 'Z'}}},
#                'template': '...',
#                'title': {'text': 'Lorenz System Simulation'},
#                'width': 700}
# })
# Output()
