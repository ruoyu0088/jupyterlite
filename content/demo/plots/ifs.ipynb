# %% [markdown]
# # Iterated function system
#
# You draw triangles, the code draws fractal image.
#
# * Ctrl + Left Click: add a new point
# * Backspace: remove the last point
# * Left Drag and Drop: move a point
# * Shift + Left Click: start moving all points, click again to finish the move

# %%
import cffi
import ipywidgets
import ipycanvas
import ipyevents
import matplotlib

# %%
from ifs import IFS

gui = IFS()
gui.layout
# Out:
# VBox(children=(HBox(children=(Dropdown(layout=Layout(width='120px'), options=('光芒四射', '蕨类植物', '旋涡', '隧道', '杂草'…
# Exception in callback WebLoop._decrement_in_progress(<PyodideTask ...s/ifs.py:286>>)
# handle: <Handle WebLoop._decrement_in_progress(<PyodideTask ...s/ifs.py:286>>)>
# Traceback (most recent call last):
#
#   File "/lib/python312.zip/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#
#   File "/lib/python312.zip/pyodide/webloop.py", line 362, in _decrement_in_progress
#     and (exc := fut.exception())
#                 ^^^^^^^^^^^^^^^
#
#   File "/drive/plots/ifs.py", line 286, in timer_task
#     async def timer_task(self):
#
# asyncio.exceptions.CancelledError
#
# Exception in callback WebLoop._decrement_in_progress(<PyodideTask ...s/ifs.py:286>>)
# handle: <Handle WebLoop._decrement_in_progress(<PyodideTask ...s/ifs.py:286>>)>
# Traceback (most recent call last):
#
#   File "/lib/python312.zip/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#
#   File "/lib/python312.zip/pyodide/webloop.py", line 362, in _decrement_in_progress
#     and (exc := fut.exception())
#                 ^^^^^^^^^^^^^^^
#
#   File "/drive/plots/ifs.py", line 286, in timer_task
#     async def timer_task(self):
#
# asyncio.exceptions.CancelledError
