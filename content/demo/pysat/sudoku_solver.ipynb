# %% [markdown]
# # 数独ソルバー
#
# * メニューRun下のRun All Cellsを実行する
# * 数独ボードをダブルクリックする
# * 矢印キーでカーソルを移動させる
# * 数字キーでカーソルのセルの数字を設定する、0は数字をクリックする

# %%
import ipycanvas, ipywidgets, ipyevents, pysat

# %%
from sudoku import SudokuCanvas
board = SudokuCanvas()
board.canvas
# Out:
# Canvas(height=400, width=400)
